# %% [markdown]
# For this exercise, we will use the Heart Disease dataset from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/heart+Disease). For homework assignment #2, we will use the consolidated dataset on [Kaggle](https://www.kaggle.com/fedesoriano/heart-failure-prediction).
#
# The goal of this notebook is to provide a gentle introduction to classification evaluation by calculating core metrics by hand from the confusion matrix.

# %%
import pandas as pd

file_loc = '../data/heart.csv'
df = pd.read_csv(file_loc)
df.head()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression

df = df[['MaxHR', 'HeartDisease']]

# define X and y
X = np.reshape(df['MaxHR'].values, (len(df), 1))
y = df['HeartDisease']

# fit a simple logistic regression model
clf = LogisticRegression(solver='lbfgs', random_state=314)
clf.fit(X, y)

# predicted probability for class 1
pred_prob = 

# quick confusion matrix at cutoff = 0.5
#--

# %%
# convert predicted probabilities to classes using cutoff = 0.5
pred_class = 

confusion_matrix_df =

# by-hand confusion matrix pieces
true_neg = 
false_pos = 
false_neg = 
true_pos =

# %% [markdown]
# ### Confusion matrix (by hand)
#
# From `confusion_matrix_df`, we extract four counts:
# - `true_neg`: actual 0, predicted 0
# - `false_pos`: actual 0, predicted 1
# - `false_neg`: actual 1, predicted 0
# - `true_pos`: actual 1, predicted 1
#
# We will now use these four numbers to calculate each metric by hand.

# %% [markdown]
# ### Accuracy

# %% [markdown]
# Definition from [scikit-learn](https://scikit-learn.org/stable/modules/model_evaluation.html).
#
# For hand calculations, we use:
# - TP = true positives
# - TN = true negatives
# - FP = false positives
# - FN = false negatives

# %% [markdown]
# $${Accuracy}(y, \hat{y}) = \frac{1}{n_\text{samples}} \sum_{i=0}^{n_\text{samples}-1} 1(\hat{y}_i = y_i)$$

# %% [markdown]
# Hand-calculation version:

# %% [markdown]
# $$ Accuracy = \frac{TP + TN}{TP + TN + FP + FN} $$

# %%
accuracy =

# %% [markdown]
# ### Sensitivity

# %% [markdown]
# $$ Sensitivity = \frac{TP}{TP + FN} $$

# %%
sensitivity =

# %% [markdown]
# ### Specificity

# %% [markdown]
# $$ Specificity = \frac{TN}{TN + FP} $$

# %%
specificity =

# %%
def model_accuracy(cutoff):

    pred_class = [1 if p >= cutoff else 0 for p in pred_prob]

    print(f'{cutoff:.2f} [{accuracy:.2f}, {sensitivity:.2f}, {specificity:.2f}]')

# %%
cutoffs = [0, 0.1, 0.25, 0.5, 0.75, 0.9, 1]

print ('Cutoff [Accuracy, Sensitivity, Specificity]')
for cutoff in cutoffs:
    model_accuracy(cutoff)

# %%
cutoffs = np.linspace(0, 1, 100)

cutoffs[:10]

# %%
def model_metrics_by_cutoff(n):

    cutoffs = np.linspace(0, 1, n)

    accu, sens, spec = [], [], []

    for cutoff in cutoffs:

        pred_class = [1 if p >= cutoff else 0 for p in pred_prob]

        cm = sk_confusion_matrix(y, pred_class)
        true_neg = cm[0, 0]
        false_pos = cm[0, 1]
        false_neg = cm[1, 0]
        true_pos = cm[1, 1]

        accu.append((true_pos + true_neg) / len(y))
        sens.append(true_pos / (true_pos + false_neg))
        spec.append(true_neg / (true_neg + false_pos))

    return cutoffs, accu, sens, spec

thresholds, accuracy, sensitivity, specificity = model_metrics_by_cutoff(100)

# %%
plt.figure(figsize=(8, 6))
plt.plot(thresholds, accuracy, color='royalblue', lw=3, label='Accuracy')
plt.plot(thresholds, sensitivity, color='tomato', lw=3, label='Sensitivity')
plt.plot(thresholds, specificity, color='olive', lw=3, label='Specificity')
plt.xlim([0.0, 1.0])
plt.xticks(np.arange(0, 1, step=0.1))
plt.xlabel('Probability Threshold Values', fontsize = 14)
plt.legend(loc='best', fontsize = 14)

# %% [markdown]
# ### Receiver Operating Characteristic (ROC) Curve

# %%
# Manual ROC calculation
# We evaluate many probability cutoffs and compute:
# TPR = TP / (TP + FN), FPR = FP / (FP + TN)

# test 100 cutoff values from 1.00 down to 0.00
thresholds = np.linspace(1, 0, 100)

fpr, tpr = [], []

for cutoff in thresholds:
    pred_class = [1 if p >= cutoff else 0 for p in pred_prob]

    cm = sk_confusion_matrix(y, pred_class)
    true_neg = cm[0, 0]
    false_pos = cm[0, 1]
    false_neg = cm[1, 0]
    true_pos = cm[1, 1]

# %%
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='royalblue', lw=3, label=f'AUC = {auc: 0.3f}')
plt.plot([0, 1], [0, 1], color='gray', lw=1, linestyle='--')
plt.xlim([0.0, 1.0])
plt.xlabel('FPR (1 - Specificity)', fontsize = 14)
plt.ylabel('TPR (Sensitivity)', fontsize = 14)
plt.legend(loc='lower right', fontsize = 14)
